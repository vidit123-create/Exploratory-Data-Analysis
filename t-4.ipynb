# %%
import pandas as pd
import re

# %%
df=pd.read_csv('C:\\Users\\arpit\\Downloads\\nrippner-titanic-disaster-dataset\\titanic.csv')
df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
sr=pd.Series(df['name'])
sr
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# 1309                                                NaN
# Name: name, Length: 1310, dtype: object

# %%
x=sr.str.extract(pat ='(Miss)')
x
# Out:
#          0
# 0     Miss
# 1      NaN
# 2     Miss
# 3      NaN
# 4      NaN
# ...    ...
# 1305  Miss
# 1306   NaN
# 1307   NaN
# 1308   NaN
# 1309   NaN
#
# [1310 rows x 1 columns]

# %%
df1=pd.DataFrame(x)
df1
# Out:
#          0
# 0     Miss
# 1      NaN
# 2     Miss
# 3      NaN
# 4      NaN
# ...    ...
# 1305  Miss
# 1306   NaN
# 1307   NaN
# 1308   NaN
# 1309   NaN
#
# [1310 rows x 1 columns]

# %%
df2=pd.concat([df,df1])
df2.head(10)
# Out:
#       0      age boat   body    cabin embarked      fare  \
# 0  Miss  29.0000    2    NaN       B5        S  211.3375
# 1   NaN   0.9167   11    NaN  C22 C26        S  151.5500
# 2  Miss   2.0000  NaN    NaN  C22 C26        S  151.5500
# 3   NaN  30.0000  NaN  135.0  C22 C26        S  151.5500
# 4   NaN  25.0000  NaN    NaN  C22 C26        S  151.5500
# 5   NaN  48.0000    3    NaN      E12        S   26.5500
# 6  Miss  63.0000   10    NaN       D7        S   77.9583
# 7   NaN  39.0000  NaN    NaN      A36        S    0.0000
# 8   NaN  53.0000    D    NaN     C101        S   51.4792
# 9   NaN  71.0000  NaN   22.0      NaN        C   49.5042
#
#                          home.dest  \
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 6                       Hudson, NY
# 7                      Belfast, NI
# ...

# %%
df2[0].unique()
# Out:
# array(['Miss', nan], dtype=object)

# %%
df2[0].value_counts()
# Out:
# Miss    520
# Name: 0, dtype: int64

# %%
y=df2.groupby(['sex',0,'name','sibsp','parch','survived']).agg({0:'count'})
y.head(10)
# Out:
#                                                                                   0
# sex    0    name                                            sibsp parch survived
# female Miss Abelseth, Miss. Karen Marie                     0.0   0.0   1.0       1
#             Allen, Miss. Elisabeth Walton                   0.0   0.0   1.0       1
#             Allison, Miss. Helen Loraine                    1.0   2.0   0.0       1
#             Andersen-Jensen, Miss. Carla Christine Nielsine 1.0   0.0   1.0       1
#             Andersson, Miss. Ebba Iris Alfrida              4.0   2.0   0.0       1
#             Andersson, Miss. Ellis Anna Maria               4.0   2.0   0.0       1
#             Andersson, Miss. Erna Alexandra                 4.0   2.0   1.0       1
#             Andersson, Miss. Ida Augusta Margareta          4.0   2.0   0.0       1
#             Andersson, Miss. Ingeborg Constanzia            4.0   2.0   0.0       1
# ...

# %%
y.tail(10)
# Out:
#                                                                          0
# sex    0    sibsp name                                   parch survived
# female Miss 4.0   Andersson, Miss. Ida Augusta Margareta 2.0   0.0       1
#                   Andersson, Miss. Ingeborg Constanzia   2.0   0.0       1
#                   Andersson, Miss. Sigrid Elisabeth      2.0   0.0       1
#                   Asplund, Miss. Lillian Gertrud         2.0   1.0       1
#             5.0   Goodwin, Miss. Jessie Allis            2.0   0.0       1
#                   Goodwin, Miss. Lillian Amy             2.0   0.0       1
#             8.0   Sage, Miss. Ada                        2.0   0.0       1
#                   Sage, Miss. Constance Gladys           2.0   0.0       1
#                   Sage, Miss. Dorothy Edith "Dolly"      2.0   0.0       1
#                   Sage, Miss. Stella Anna                2.0   0.0       1

# %%
df3=df.groupby(['sex','name',0]).agg({0:'count'})
df3.head(20)
# Out:
#                                                              0
# sex    name                                            0
# female Abelseth, Miss. Karen Marie                     Miss  1
#        Allen, Miss. Elisabeth Walton                   Miss  1
#        Allison, Miss. Helen Loraine                    Miss  1
#        Andersen-Jensen, Miss. Carla Christine Nielsine Miss  1
#        Andersson, Miss. Ebba Iris Alfrida              Miss  1
#        Andersson, Miss. Ellis Anna Maria               Miss  1
#        Andersson, Miss. Erna Alexandra                 Miss  1
#        Andersson, Miss. Ida Augusta Margareta          Miss  1
#        Andersson, Miss. Ingeborg Constanzia            Miss  1
#        Andersson, Miss. Sigrid Elisabeth               Miss  1
#        Andrews, Miss. Kornelia Theodosia               Miss  1
#        Asplund, Miss. Lillian Gertrud                  Miss  1
#        Attalah, Miss. Malake                           Miss  1
# ...

# %%
x=df2.groupby([0])
y=x.filter(lambda z: any(z[0]=='Miss'))
y
# Out:
#          0   age boat  body    cabin embarked      fare  \
# 0     Miss  29.0    2   NaN       B5        S  211.3375
# 2     Miss   2.0  NaN   NaN  C22 C26        S  151.5500
# 6     Miss  63.0   10   NaN       D7        S   77.9583
# 13    Miss  26.0    6   NaN      NaN        S   78.8500
# 18    Miss  32.0    8   NaN      D15        C   76.2917
# ...    ...   ...  ...   ...      ...      ...       ...
# 1265  Miss   NaN  NaN   NaN      NaN      NaN       NaN
# 1273  Miss   NaN  NaN   NaN      NaN      NaN       NaN
# 1279  Miss   NaN  NaN   NaN      NaN      NaN       NaN
# 1304  Miss   NaN  NaN   NaN      NaN      NaN       NaN
# 1305  Miss   NaN  NaN   NaN      NaN      NaN       NaN
#
#                             home.dest                               name  \
# 0                        St Louis, MO      Allen, Miss. Elisabeth Walton
# 2     Montreal, PQ / Chesterville, ON       Allison, Miss. Helen Loraine
# ...
