# %%
#Import libraries :-

# %%
import pandas as pd
import numpy as np

# %%
#Create DataFrame :-

# %%
df=pd.DataFrame({'From_To':['LoNDon_paris','MAdrid_miLAN','londON_StockhOlm','Budapest_PaRis','Brussels_londOn'],'FlightNumber':[10045,np.nan,10065,np.nan,10085],'RecentDelays':[[23,47],[],[24,43,87],[13],[67,32]],'Airline':['KLM(!)','<AirFrance>(12)','(British.Airways.)','12.AirFrance','''SwissAir''']})
df
# Out:
#             From_To  FlightNumber  RecentDelays             Airline
# 0      LoNDon_paris       10045.0      [23, 47]              KLM(!)
# 1      MAdrid_miLAN           NaN            []     <AirFrance>(12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British.Airways.)
# 3    Budapest_PaRis           NaN          [13]        12.AirFrance
# 4   Brussels_londOn       10085.0      [67, 32]            SwissAir

# %% [markdown]
# # Task-2 :-Data Cleaning Assignment

# %% [markdown]
# #### 1.Fill the missing value and convert its datatype present in integer into float.

# %%
x=int(input())
X=df.loc[[1],['FlightNumber']].fillna(10045.0+x)
X
# Out:
# 10
#    FlightNumber
# 1       10055.0

# %%
df.loc[[1],['FlightNumber']]=X
df
# Out:
#             From_To  FlightNumber  RecentDelays             Airline
# 0      LoNDon_paris       10045.0      [23, 47]              KLM(!)
# 1      MAdrid_miLAN       10055.0            []     <AirFrance>(12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British.Airways.)
# 3    Budapest_PaRis           NaN          [13]        12.AirFrance
# 4   Brussels_londOn       10085.0      [67, 32]            SwissAir

# %%
y=10
Y=df.loc[[3],['FlightNumber']].fillna(10065.0+y)
Y
# Out:
#    FlightNumber
# 3       10075.0

# %%
df.loc[[3],['FlightNumber']]=Y
df
# Out:
#             From_To  FlightNumber  RecentDelays             Airline
# 0      LoNDon_paris       10045.0      [23, 47]              KLM(!)
# 1      MAdrid_miLAN       10055.0            []     <AirFrance>(12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British.Airways.)
# 3    Budapest_PaRis       10075.0          [13]        12.AirFrance
# 4   Brussels_londOn       10085.0      [67, 32]            SwissAir

# %%
df.FlightNumber.dtype
# Out:
# dtype('float64')

# %%
df['FlightNumber']=df[['FlightNumber']].astype(int)
df
# Out:
#             From_To  FlightNumber  RecentDelays             Airline
# 0      LoNDon_paris         10045      [23, 47]              KLM(!)
# 1      MAdrid_miLAN         10055            []     <AirFrance>(12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British.Airways.)
# 3    Budapest_PaRis         10075          [13]        12.AirFrance
# 4   Brussels_londOn         10085      [67, 32]            SwissAir

# %% [markdown]
# #### 2.Split the From_To column into separate column and assign a temporary dataframes and assign a new column to it.

# %%
X=df[['From_To']]
X
# Out:
#             From_To
# 0      LoNDon_paris
# 1      MAdrid_miLAN
# 2  londON_StockhOlm
# 3    Budapest_PaRis
# 4   Brussels_londOn

# %%
def a(data):
    data=str(data)
    data1=data.split('_')
    return data1
df1=X['From_To'].apply(a)
df1
# Out:
# 0        [LoNDon, paris]
# 1        [MAdrid, miLAN]
# 2    [londON, StockhOlm]
# 3      [Budapest, PaRis]
# 4     [Brussels, londOn]
# Name: From_To, dtype: object

# %%
list=df1.values.tolist()
list
# Out:
# [['LoNDon', 'paris'],
#  ['MAdrid', 'miLAN'],
#  ['londON', 'StockhOlm'],
#  ['Budapest', 'PaRis'],
#  ['Brussels', 'londOn']]

# %%
df2=pd.DataFrame(list,columns=['Startdestination','Stopdestination'])
df2
# Out:
#   Startdestination Stopdestination
# 0           LoNDon           paris
# 1           MAdrid           miLAN
# 2           londON       StockhOlm
# 3         Budapest           PaRis
# 4         Brussels          londOn

# %% [markdown]
# #### 3.Capitalize the strings present in the both columns.

# %%
def a(data):
    data=str(data)
    data1=data.capitalize()
    return data1
df2['Start_Destination']=df2['Startdestination'].apply(a)
df2
# Out:
#   Startdestination Stopdestination Start_Destination
# 0           LoNDon           paris            London
# 1           MAdrid           miLAN            Madrid
# 2           londON       StockhOlm            London
# 3         Budapest           PaRis          Budapest
# 4         Brussels          londOn          Brussels

# %%
def a(data):
    data=str(data)
    data1=data.capitalize()
    return data1
df2['Stop_Destination']=df2['Stopdestination'].apply(a)
df2
# Out:
#   Startdestination Stopdestination Start_Destination Stop_Destination
# 0           LoNDon           paris            London            Paris
# 1           MAdrid           miLAN            Madrid            Milan
# 2           londON       StockhOlm            London        Stockholm
# 3         Budapest           PaRis          Budapest            Paris
# 4         Brussels          londOn          Brussels           London

# %%
#Drop the previous columns from the newly created dataframes :-

# %%
df2.drop(['Startdestination','Stopdestination'],axis=1,inplace=True)
df2
# Out:
#   Start_Destination Stop_Destination
# 0            London            Paris
# 1            Madrid            Milan
# 2            London        Stockholm
# 3          Budapest            Paris
# 4          Brussels           London

# %%
#Assign to a new dataframes :-

# %%
df3=df2
df3
# Out:
#   Start_Destination Stop_Destination
# 0            London            Paris
# 1            Madrid            Milan
# 2            London        Stockholm
# 3          Budapest            Paris
# 4          Brussels           London

# %% [markdown]
# #### 4.Delete From_To column from the old dataframe and attached this column to the newly created dataframe.

# %%
df.drop(['From_To'],axis=1,inplace=True)
df
# Out:
#    FlightNumber  RecentDelays             Airline
# 0       10045.0      [23, 47]              KLM(!)
# 1       10055.0            []     <AirFrance>(12)
# 2       10065.0  [24, 43, 87]  (British.Airways.)
# 3       10075.0          [13]        12.AirFrance
# 4       10085.0      [67, 32]            SwissAir

# %%
df['Start_Dest']=df3['Start_Destination']
df
# Out:
#    FlightNumber  RecentDelays             Airline Start_Dest
# 0       10045.0      [23, 47]              KLM(!)     London
# 1       10055.0            []     <AirFrance>(12)     Madrid
# 2       10065.0  [24, 43, 87]  (British.Airways.)     London
# 3       10075.0          [13]        12.AirFrance   Budapest
# 4       10085.0      [67, 32]            SwissAir   Brussels

# %%
df['Stop_Dest']=df3['Stop_Destination']
df
# Out:
#    FlightNumber  RecentDelays             Airline Start_Dest  Stop_Dest
# 0       10045.0      [23, 47]              KLM(!)     London      Paris
# 1       10055.0            []     <AirFrance>(12)     Madrid      Milan
# 2       10065.0  [24, 43, 87]  (British.Airways.)     London  Stockholm
# 3       10075.0          [13]        12.AirFrance   Budapest      Paris
# 4       10085.0      [67, 32]            SwissAir   Brussels     London

# %% [markdown]
# #### 5.Split the RecentDelays column into separate columns by just splitting the list to there corresponding columns and then provide the new columns a dataframe and also rename the columns and then remove the RecentDelays column with these newly created columns.

# %%
list=df['RecentDelays'].values.tolist()
list
# Out:
# [[23, 47], [], [24, 43, 87], [13], [67, 32]]

# %%
delays=pd.DataFrame(list,columns=['delays1','delays2','delays3'])
delays
# Out:
#    delays1  delays2  delays3
# 0     23.0     47.0      NaN
# 1      NaN      NaN      NaN
# 2     24.0     43.0     87.0
# 3     13.0      NaN      NaN
# 4     67.0     32.0      NaN

# %%
df['Delays1']=delays['delays1']
df
# Out:
#    FlightNumber  RecentDelays             Airline Start_Dest  Stop_Dest  \
# 0       10045.0      [23, 47]              KLM(!)     London      Paris
# 1       10055.0            []     <AirFrance>(12)     Madrid      Milan
# 2       10065.0  [24, 43, 87]  (British.Airways.)     London  Stockholm
# 3       10075.0          [13]        12.AirFrance   Budapest      Paris
# 4       10085.0      [67, 32]            SwissAir   Brussels     London
#
#    Delays1
# 0     23.0
# 1      NaN
# 2     24.0
# 3     13.0
# 4     67.0

# %%
df['Delays2']=delays['delays2']
df
# Out:
#    FlightNumber  RecentDelays             Airline Start_Dest  Stop_Dest  \
# 0       10045.0      [23, 47]              KLM(!)     London      Paris
# 1       10055.0            []     <AirFrance>(12)     Madrid      Milan
# 2       10065.0  [24, 43, 87]  (British.Airways.)     London  Stockholm
# 3       10075.0          [13]        12.AirFrance   Budapest      Paris
# 4       10085.0      [67, 32]            SwissAir   Brussels     London
#
#    Delays1  Delays2
# 0     23.0     47.0
# 1      NaN      NaN
# 2     24.0     43.0
# 3     13.0      NaN
# 4     67.0     32.0

# %%
df['Delays3']=delays['delays3']
df
# Out:
#    FlightNumber  RecentDelays             Airline Start_Dest  Stop_Dest  \
# 0       10045.0      [23, 47]              KLM(!)     London      Paris
# 1       10055.0            []     <AirFrance>(12)     Madrid      Milan
# 2       10065.0  [24, 43, 87]  (British.Airways.)     London  Stockholm
# 3       10075.0          [13]        12.AirFrance   Budapest      Paris
# 4       10085.0      [67, 32]            SwissAir   Brussels     London
#
#    Delays1  Delays2  Delays3
# 0     23.0     47.0      NaN
# 1      NaN      NaN      NaN
# 2     24.0     43.0     87.0
# 3     13.0      NaN      NaN
# 4     67.0     32.0      NaN

# %%
#Drop the RecentDelays column:-

# %%
df.drop(['RecentDelays'],axis=1,inplace=True)
df
# Out:
#    FlightNumber             Airline Start_Dest  Stop_Dest  Delays1  Delays2  \
# 0       10045.0              KLM(!)     London      Paris     23.0     47.0
# 1       10055.0     <AirFrance>(12)     Madrid      Milan      NaN      NaN
# 2       10065.0  (British.Airways.)     London  Stockholm     24.0     43.0
# 3       10075.0        12.AirFrance   Budapest      Paris     13.0      NaN
# 4       10085.0            SwissAir   Brussels     London     67.0     32.0
#
#    Delays3
# 0      NaN
# 1      NaN
# 2     87.0
# 3      NaN
# 4      NaN

# %% [markdown]
# ### Resultant Output of all the question which I have solved :-

# %%
df4=df
df4
# Out:
#    FlightNumber             Airline Start_Dest  Stop_Dest  Delays1  Delays2  \
# 0       10045.0              KLM(!)     London      Paris     23.0     47.0
# 1       10055.0     <AirFrance>(12)     Madrid      Milan      NaN      NaN
# 2       10065.0  (British.Airways.)     London  Stockholm     24.0     43.0
# 3       10075.0        12.AirFrance   Budapest      Paris     13.0      NaN
# 4       10085.0            SwissAir   Brussels     London     67.0     32.0
#
#    Delays3
# 0      NaN
# 1      NaN
# 2     87.0
# 3      NaN
# 4      NaN
